# %% [markdown]
# # Loading Packages and Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\rehan\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#To read the file
df=pd.read_excel(r"C:\Users\rehan\Downloads\techno_loan_file.xlsx")

# %% [markdown]
# # Data Structure and Content

# %%
df
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0                 0            199902                  N        202901  16974
# 1                 0            199902                  N        202901  19740
# 2                 0            199902                  N        202901  29940
# 3                 0            199902                  N        202901  31084
# 4                 0            199902                  N        202901  35644
# ...             ...               ...                ...           ...    ...
# 291446          839            199903                  N        202902  37964
# 291447          840            200210                  N        202904  35644
# 291448          840            200304                  N        202904  42044
# 291449          845            199904                  N        202903  37964
# 291450          849            199903                  N        202902  37964
#
# ...

# %%
#To check all columns
pd.set_option('display.max_columns',None)
df
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0                 0            199902                  N        202901  16974
# 1                 0            199902                  N        202901  19740
# 2                 0            199902                  N        202901  29940
# 3                 0            199902                  N        202901  31084
# 4                 0            199902                  N        202901  35644
# ...             ...               ...                ...           ...    ...
# 291446          839            199903                  N        202902  37964
# 291447          840            200210                  N        202904  35644
# 291448          840            200304                  N        202904  42044
# 291449          845            199904                  N        202903  37964
# 291450          849            199903                  N        202902  37964
#
# ...

# %%
#To see first five rows
df.head()
# Out:
#    CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  MIP  \
# 0            0            199902                  N        202901  16974   25
# 1            0            199902                  N        202901  19740    0
# 2            0            199902                  N        202901  29940    0
# 3            0            199902                  N        202901  31084    0
# 4            0            199902                  N        202901  35644    0
#
#    Units Occupancy  OCLTV  DTI  OrigUPB  LTV  OrigInterestRate Channel PPM  \
# 0      1         O     89   27   117000   89             6.750       T   N
# 1      1         O     73   17   109000   73             6.500       R   N
# 2      1         O     75   16    88000   75             6.875       T   N
# 3      1         O     76   14   160000   76             6.875       R   N
# 4      1         O     78   18   109000   78             7.125       R   N
#
# ...

# %%
#To see random five rows
df.sample(5)
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 103848          694            199905                  N        202904  45300
# 244908          765            199904                  X        202903  24340
# 20615           630            199905                  N        202904  37964
# 195275          742            199903                  N        202902  46700
# 79410           679            199905                  N        202904  X
#
#         MIP  Units Occupancy  OCLTV  DTI  OrigUPB  LTV  OrigInterestRate  \
# 103848    0      2         I     60   20    48000   60             7.375
# 244908   25      1         O     90   34   164000   90             7.125
# 20615     0      1         O     76   19   186000   76             7.250
# 195275   25      1         O     88   14   185000   88             6.750
# 79410    25      1         O     90   46    98000   90             7.125
#
# ...

# %% [markdown]
# # Data Information

# %%
#To check each column data type,non null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291451 entries, 0 to 291450
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CreditScore         291451 non-null  int64
#  1   FirstPaymentDate    291451 non-null  int64
#  2   FirstTimeHomebuyer  291451 non-null  object
#  3   MaturityDate        291451 non-null  int64
#  4   MSA                 291451 non-null  object
#  5   MIP                 291451 non-null  int64
#  6   Units               291451 non-null  int64
#  7   Occupancy           291451 non-null  object
#  8   OCLTV               291451 non-null  int64
#  9   DTI                 291451 non-null  int64
#  10  OrigUPB             291451 non-null  int64
#  11  LTV                 291451 non-null  int64
#  12  OrigInterestRate    291451 non-null  float64
#  13  Channel             291451 non-null  object
#  14  PPM                 291451 non-null  object
# ...

# %%
#To see total number of rows and columns
df.shape
# Out:
# (291451, 28)

# %%
#To see statistical summary of data
df.describe()
# Out:
#          CreditScore  FirstPaymentDate   MaturityDate            MIP  \
# count  291451.000000     291451.000000  291451.000000  291451.000000
# mean      708.936991     199904.760553  202902.367043       9.216685
# std        68.408791         13.821228      16.090508      12.648273
# min         0.000000     199901.000000  202402.000000       0.000000
# 25%       675.000000     199903.000000  202902.000000       0.000000
# 50%       717.000000     199904.000000  202903.000000       0.000000
# 75%       753.000000     199905.000000  202904.000000      25.000000
# max       849.000000     201303.000000  204302.000000      55.000000
#
#                Units          OCLTV            DTI        OrigUPB  \
# count  291451.000000  291451.000000  291451.000000  291451.000000
# mean        1.026022      76.960529      30.033453  124940.387921
# std         0.202986      15.236154      13.203974   53657.440624
# min         0.000000       0.000000       0.000000    8000.000000
# ...

# %%
#To check unique values in each column
df.apply(lambda x:len(x.unique()))
# Out:
# CreditScore              370
# FirstPaymentDate          66
# FirstTimeHomebuyer         3
# MaturityDate              96
# MSA                      392
# MIP                       37
# Units                      5
# Occupancy                  3
# OCLTV                    102
# DTI                       66
# OrigUPB                  375
# LTV                       97
# OrigInterestRate         254
# Channel                    4
# PPM                        3
# ProductType                1
# PropertyState             53
# PropertyType               7
# PostalCode               892
# LoanSeqNum            291451
# LoanPurpose                3
# OrigLoanTerm              61
# NumBorrowers               3
# SellerName                21
# ServicerName              20
# EverDelinquent             2
# MonthsDelinquent         174
# MonthsInRepayment        212
# dtype: int64

# %%
df['EverDelinquent'].value_counts()
# Out:
# EverDelinquent
# 0    233788
# 1     57663
# Name: count, dtype: int64

# %%
df['FirstTimeHomebuyer'].value_counts()
# Out:
# FirstTimeHomebuyer
# N    184154
# X     78015
# Y     29282
# Name: count, dtype: int64

# %%
print(78015/291451)
print(184154/291451)
# Out:
# 0.2676779287084278
# 0.631852352539535

# %%
df['Units'].value_counts()
# Out:
# Units
# 1    285598
# 2      4690
# 3       587
# 4       574
# 0         2
# Name: count, dtype: int64

# %%
df['Occupancy'].value_counts()
# Out:
# Occupancy
# O    276131
# I      8734
# S      6586
# Name: count, dtype: int64

# %%
df['Channel'].value_counts()
# Out:
# Channel
# T    167670
# R    123219
# C       407
# B       155
# Name: count, dtype: int64

# %%
df['PPM'].value_counts()
# Out:
# PPM
# N    282125
# X      5405
# Y      3921
# Name: count, dtype: int64

# %%
(5405/291451)*100
# Out:
# 1.8545141378825256

# %%
df['PropertyType'].value_counts()
# Out:
# PropertyType
# SF    244923
# PU     27506
# CO     18100
# MH       723
# LH       105
# CP        72
# X         22
# Name: count, dtype: int64

# %%
df['LoanPurpose'].value_counts()
# Out:
# LoanPurpose
# P    123404
# N    110036
# C     58011
# Name: count, dtype: int64

# %%
df['NumBorrowers'].value_counts()
# Out:
# NumBorrowers
# 2     187335
# 1     103777
# X        339
# Name: count, dtype: int64

# %%
df['MSA'].value_counts()
# Out:
# MSA
# X        39100
# 31084     9338
# 16974     8771
# 12060     6985
# 47644     6673
#          ...
# 21940        3
# 49500        2
# 25020        1
# 10380        1
# 32420        1
# Name: count, Length: 392, dtype: int64

# %%
df['PostalCode'].value_counts()
# Out:
# PostalCode
# 94500    3776
# 30000    3637
# 85200    3280
# 48100    3246
# 48000    2988
#          ...
# 79200       1
# 77200       1
# 5900        1
# 87200       1
# 41300       1
# Name: count, Length: 892, dtype: int64

# %%
df['DTI'].value_counts()
# Out:
# DTI
# 0     17796
# 28    12818
# 36     9493
# 33     9378
# 35     9297
#       ...
# 63      272
# 65      207
# 3       180
# 2       109
# 1        64
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# # Dropping out Unwanted Data

# %%
df.drop(['FirstPaymentDate','MaturityDate','ProductType','LoanSeqNum'],axis=1,inplace=True)
df
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 0                 0                  N  16974   25      1         O     89
# 1                 0                  N  19740    0      1         O     73
# 2                 0                  N  29940    0      1         O     75
# 3                 0                  N  31084    0      1         O     76
# 4                 0                  N  35644    0      1         O     78
# ...             ...                ...    ...  ...    ...       ...    ...
# 291446          839                  N  37964    0      1         O     60
# 291447          840                  N  35644    0      1         O     73
# 291448          840                  N  42044    0      1         O     73
# 291449          845                  N  37964    0      1         I     80
# 291450          849                  N  37964    0      1         O     47
#
# ...

# %%
#dropped above four column as FirstPaymentDate,MaturityDate is given and we don't reqquire to perform time series analysis,
#dropped ProductType as all product are same
#dropped LoanSeqNum as it is unique id and can't make any analysis from this

# %% [markdown]
# # checking for Null Values

# %%
df.isnull().sum()
# Out:
# CreditScore               0
# FirstTimeHomebuyer        0
# MSA                       0
# MIP                       0
# Units                     0
# Occupancy                 0
# OCLTV                     0
# DTI                       0
# OrigUPB                   0
# LTV                       0
# OrigInterestRate          0
# Channel                   0
# PPM                       0
# PropertyState             0
# PropertyType              0
# PostalCode                0
# LoanPurpose               0
# OrigLoanTerm              0
# NumBorrowers              0
# SellerName            24994
# ServicerName              0
# EverDelinquent            0
# MonthsDelinquent          0
# MonthsInRepayment         0
# dtype: int64

# %%
#To find the percentage of null values in each column
df.isnull().mean()*100
# Out:
# CreditScore           0.000000
# FirstTimeHomebuyer    0.000000
# MSA                   0.000000
# MIP                   0.000000
# Units                 0.000000
# Occupancy             0.000000
# OCLTV                 0.000000
# DTI                   0.000000
# OrigUPB               0.000000
# LTV                   0.000000
# OrigInterestRate      0.000000
# Channel               0.000000
# PPM                   0.000000
# PropertyState         0.000000
# PropertyType          0.000000
# PostalCode            0.000000
# LoanPurpose           0.000000
# OrigLoanTerm          0.000000
# NumBorrowers          0.000000
# SellerName            8.575713
# ServicerName          0.000000
# EverDelinquent        0.000000
# MonthsDelinquent      0.000000
# MonthsInRepayment     0.000000
# dtype: float64

# %% [markdown]
# # Handling null values

# %%
df['SellerName'].value_counts()
# Out:
# SellerName
# Ot    76943
# CO    34479
# FL    25573
# FI    24581
# ST    22243
# NO    16184
# OL     7776
# PR     7365
# BA     7093
# GM     6566
# BI     6407
# G      4734
# CH     4599
# CR     4459
# FT     4105
# WA     3139
# AC     3076
# HO     2970
# PN     2407
# RE     1758
# Name: count, dtype: int64

# %%
76943/291451
# Out:
# 0.26399978040905675

# %%
#To show countplot with label
ax=sns.countplot(df,x='SellerName')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '25573'),
#  Text(0, 0, '4105'),
#  Text(0, 0, '6566'),
#  Text(0, 0, '76943'),
#  Text(0, 0, '1758'),
#  Text(0, 0, '16184'),
#  Text(0, 0, '22243'),
#  Text(0, 0, '4459'),
#  Text(0, 0, '4599'),
#  Text(0, 0, '24581'),
#  Text(0, 0, '2970'),
#  Text(0, 0, '7365'),
#  Text(0, 0, '2407'),
#  Text(0, 0, '3139'),
#  Text(0, 0, '7093'),
#  Text(0, 0, '4734'),
#  Text(0, 0, '7776'),
#  Text(0, 0, '3076'),
#  Text(0, 0, '34479'),
#  Text(0, 0, '6407')]

# %%
#To find mode
df['SellerName'].mode()
# Out:
# 0    Ot
# Name: SellerName, dtype: object

# %%
#To fill missing values with mode
df['SellerName'].fillna('Ot',inplace=True)
print(df)
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 0                 0                  N  16974   25      1         O     89
# 1                 0                  N  19740    0      1         O     73
# 2                 0                  N  29940    0      1         O     75
# 3                 0                  N  31084    0      1         O     76
# 4                 0                  N  35644    0      1         O     78
# ...             ...                ...    ...  ...    ...       ...    ...
# 291446          839                  N  37964    0      1         O     60
# 291447          840                  N  35644    0      1         O     73
# 291448          840                  N  42044    0      1         O     73
# 291449          845                  N  37964    0      1         I     80
# 291450          849                  N  37964    0      1         O     47
#
# ...

# %%
df['SellerName'].value_counts()
# Out:
# SellerName
# Ot    101937
# CO     34479
# FL     25573
# FI     24581
# ST     22243
# NO     16184
# OL      7776
# PR      7365
# BA      7093
# GM      6566
# BI      6407
# G       4734
# CH      4599
# CR      4459
# FT      4105
# WA      3139
# AC      3076
# HO      2970
# PN      2407
# RE      1758
# Name: count, dtype: int64

# %%
#replace x that is undefined from mode value in categorical column
df.replace('X',np.nan,inplace=True)
df.sample(5)
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 217143          752                NaN  19804    0      1         O     78
# 248305          767                  N  42044    0      1         O     50
# 255120          770                  N  16974    0      1         O     60
# 141459          715                  N  37764    0      1         O     70
# 170724          730                  N  35380    0      1         O     80
#
#         DTI  OrigUPB  LTV  OrigInterestRate Channel PPM PropertyState  \
# 217143   21   130000   78             6.750       R   N            MI
# 248305   37   200000   50             6.875       R   Y            CA
# 255120   26   170000   60             7.000       T   N            IL
# 141459   40   200000   70             7.125       R   N            MA
# 170724   31    83000   80             6.750       R   N            LA
#
#        PropertyType PostalCode LoanPurpose  OrigLoanTerm NumBorrowers  \
# ...

# %%
df.isnull().sum()
# Out:
# CreditScore               0
# FirstTimeHomebuyer    78015
# MSA                       0
# MIP                       0
# Units                     0
# Occupancy                 0
# OCLTV                     0
# DTI                       0
# OrigUPB                   0
# LTV                       0
# OrigInterestRate          0
# Channel                   0
# PPM                    5405
# PropertyState             0
# PropertyType              0
# PostalCode                0
# LoanPurpose               0
# OrigLoanTerm              0
# NumBorrowers              0
# SellerName                0
# ServicerName              0
# EverDelinquent            0
# MonthsDelinquent          0
# MonthsInRepayment         0
# dtype: int64

# %%
columns=['CreditScore','FirstTimeHomebuyer','MSA','MIP','Units','Occupancy','OCLTV','DTI','OrigUPB','LTV','OrigInterestRate','Channel','PPM','PropertyState','PropertyType','PostalCode','LoanPurpose','OrigLoanTerm','NumBorrowers','SellerName','ServicerName','EverDelinquent','MonthsDelinquent','MonthsInRepayment']

# %%
for column in df.columns:
    mode_value = df[column].mode()[0]  # Get the mode for the column
    df[column].fillna(mode_value, inplace=True)  # Fill missing values with the mode
# Out:
# C:\Users\rehan\AppData\Local\Temp\ipykernel_31696\2599760866.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(mode_value, inplace=True)  # Fill missing values with the mode
# C:\Users\rehan\AppData\Local\Temp\ipykernel_31696\2599760866.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#null value removed
df.isnull().sum()
# Out:
# CreditScore           0
# FirstTimeHomebuyer    0
# MSA                   0
# MIP                   0
# Units                 0
# Occupancy             0
# OCLTV                 0
# DTI                   0
# OrigUPB               0
# LTV                   0
# OrigInterestRate      0
# Channel               0
# PPM                   0
# PropertyState         0
# PropertyType          0
# PostalCode            0
# LoanPurpose           0
# OrigLoanTerm          0
# NumBorrowers          0
# SellerName            0
# ServicerName          0
# EverDelinquent        0
# MonthsDelinquent      0
# MonthsInRepayment     0
# dtype: int64

# %%
#calculate the mode of first time home buyer
mode_value=df['FirstTimeHomebuyer'].mode()
mode_value
# Out:
# 0    N
# Name: FirstTimeHomebuyer, dtype: object

# %%
#replace null values with the mode
df['FirstTimeHomebuyer'].fillna('N',inplace=True)
df.sample(5)
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 286619          796                  N  X        0      1         O     57
# 68926           672                  N  31340    0      1         O     80
# 9239            610                  N  45820   30      1         O     95
# 129150          708                  N  42044    0      1         O     74
# 154210          721                  Y  X       25      1         O     90
#
#         DTI  OrigUPB  LTV  OrigInterestRate Channel PPM PropertyState  \
# 286619   37   214000   57             7.000       T   N            CO
# 68926    29    80000   80             7.000       T   N            VA
# 9239     42    56000   95             6.750       R   N            KS
# 129150   56   168000   74             6.750       T   N            CA
# 154210   46    68000   90             6.875       T   N            PA
#
#        PropertyType PostalCode LoanPurpose  OrigLoanTerm NumBorrowers  \
# ...

# %%
df['FirstTimeHomebuyer'].value_counts()
# Out:
# FirstTimeHomebuyer
# N    262169
# Y     29282
# Name: count, dtype: int64

# %%
#calculate the mode of first time home buyer
mode_value=df['PPM'].mode()
mode_value
# Out:
# 0    N
# Name: PPM, dtype: object

# %%
#replace null values with the mode
df['PPM'].fillna('N',inplace=True)
df.sample(5)
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 279121          787                  N  16300    0      1         O     64
# 153552          721                  N  16860    0      1         O     80
# 183488          736                  N  45300   25      1         O     90
# 15121           622                  Y  26420    0      1         O     32
# 95125           689                  N  38060   30      1         O     95
#
#         DTI  OrigUPB  LTV  OrigInterestRate Channel PPM PropertyState  \
# 279121   19   110000   64             6.500       T   N            IA
# 153552   20    71000   80             7.000       T   N            TN
# 183488   40   131000   90             6.250       R   N            FL
# 15121    44    40000   32             6.875       R   N            TX
# 95125    46    88000   95             7.500       T   N            AZ
#
#        PropertyType PostalCode LoanPurpose  OrigLoanTerm NumBorrowers  \
# ...

# %%
df['MSA'].unique()
# Out:
# array([16974, 19740, 29940, 31084, 35644, 'X    ', 36740, 25540, 48620,
#        12060, 12420, 13140, 13644, 15764, 16700, 16940, 17900, 19124,
#        20500, 20764, 21340, 22380, 22744, 23060, 23104, 24660, 24860,
#        25060, 26900, 27060, 27140, 27260, 28420, 29404, 30780, 31340,
#        33124, 33340, 33460, 34820, 35004, 35084, 35380, 37100, 38060,
#        38300, 38900, 39300, 39340, 39820, 40060, 40140, 40900, 41180,
#        41620, 41700, 41740, 41884, 42044, 42220, 42644, 43900, 46060,
#        46700, 47644, 47894, 49180, 49420, 11340, 12100, 14500, 17820,
#        17860, 19340, 19804, 28140, 29740, 36084, 36500, 37460, 42060,
#        47260, 48424, 12580, 14484, 14860, 19380, 26420, 29420, 29620,
#        36540, 37764, 37860, 37964, 38940, 40380, 45300, 19660, 11300,
#        11460, 12220, 12940, 13820, 13980, 14740, 15540, 16740, 17140,
#        17460, 17780, 22220, 23420, 23844, 24340, 24780, 26180, 27620,
# ...

# %%
try:
    pd.to_numeric(df['MSA'])
    print("All values in the column are numeric.")
except ValueError:
    print("The column contains non-numeric values.")
# Out:
# The column contains non-numeric values.

# %%
df = df[df['MSA'] != 'X    ']

# %%
try:
    pd.to_numeric(df['MSA'])
    print("All values in the column are numeric.")
except ValueError:
    print("The column contains non-numeric values.")
# Out:
# All values in the column are numeric.

# %%
df['MSA'] = df['MSA'].astype('int64')
# Out:
# C:\Users\rehan\AppData\Local\Temp\ipykernel_31696\413381289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MSA'] = df['MSA'].astype('int64')

# %%
#check data type of MSA
dt=df['MSA'].dtype
print(dt)
# Out:
# int64

# %%
df['PostalCode'].unique()
# Out:
# array([60400, 80200, 66000, 90700, 7600, 32800, 6400, 67000, 30100, 30000,
#        30600, 30200, 30300, 78700, 77700, 20800, 1800, 29400, 82000,
#        60000, 60200, 60600, 60100, 29000, 75200, 27500, 7700, 79900,
#        86000, 33300, 33000, 46800, 76100, 27400, 29600, 39500, 6100,
#        46000, 14800, 39100, 32200, 99300, 72200, 91300, 91700, 24500,
#        33100, 53000, 53100, 55300, 55400, 29500, 11900, 7000, 7900, 70000,
#        7400, 11400, 85200, 85300, 15000, 97200, 97000, 2800, 2000, 84000,
#        96000, 23200, 92200, 92800, 95600, 95800, 62200, 78200, 92100,
#        94400, 92600, 95400, 98200, 98000, 98100, 29300, 85700, 94500,
#        48100, 48300, 48000, 20100, 22300, 22200, 27100, 98900, 8200,
#        80300, 2100, 80900, 65200, 52700, 80100, 8500, 66100, 88000, 90200,
#        55100, 10300, 98500, 32400, 85000, 96100, 92000, 92700, 93400,
#        23600, 33400, 67200, 21200, 2300, 6600, 45300, 48200, 8800, 77000,
# ...

# %%
try:
    pd.to_numeric(df['PostalCode'])
    print("All values in the column are numeric.")
except ValueError:
    print("The column contains non-numeric values.")
# Out:
# The column contains non-numeric values.

# %%
df = df[pd.to_numeric(df['PostalCode'], errors='coerce').notnull()]

# %%
try:
    pd.to_numeric(df['PostalCode'])
    print("All values in the column are numeric.")
except ValueError:
    print("The column contains non-numeric values.")
# Out:
# All values in the column are numeric.

# %%
df['PostalCode'] = df['PostalCode'].astype('int64')
# Out:
# C:\Users\rehan\AppData\Local\Temp\ipykernel_31696\462123791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PostalCode'] = df['PostalCode'].astype('int64')

# %%
#check data type of PostalCode
dt=df['PostalCode'].dtype
print(dt)
# Out:
# int64

# %%
df['NumBorrowers'].unique()
# Out:
# array([2, 1, 'X '], dtype=object)

# %%
df['NumBorrowers'].value_counts()
# Out:
# NumBorrowers
# 2    161006
# 1     91054
# Name: count, dtype: int64

# %%
try:
    pd.to_numeric(df['NumBorrowers'])
    print("All values in the column are numeric.")
except ValueError:
    print("The column contains non-numeric values.")
# Out:
# All values in the column are numeric.

# %%
df = df[pd.to_numeric(df['NumBorrowers'], errors='coerce').notnull()]

# %%
try:
    pd.to_numeric(df['NumBorrowers'])
    print("All values in the column are numeric.")
except ValueError:
    print("The column contains non-numeric values.")
# Out:
# All values in the column are numeric.

# %%
df.drop(df[df['NumBorrowers'] == 'X '].index, inplace=True)

# %%
df['NumBorrowers'].unique()
# Out:
# array([2, 1], dtype=object)

# %%
df['NumBorrowers'] = df['NumBorrowers'].astype('int64')

# %%
#check data type of NumBorroers
dt=df['NumBorrowers'].dtype
print(dt)
# Out:
# int64

# %%
#converted all x that is undefined

# %% [markdown]
# # Check for Duplicate Value

# %%
df.duplicated().sum()
# Out:
# 32

# %%
df.drop_duplicates()
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 0                 0                  N  16974   25      1         O     89
# 1                 0                  N  19740    0      1         O     73
# 2                 0                  N  29940    0      1         O     75
# 3                 0                  N  31084    0      1         O     76
# 4                 0                  N  35644    0      1         O     78
# ...             ...                ...    ...  ...    ...       ...    ...
# 291446          839                  N  37964    0      1         O     60
# 291447          840                  N  35644    0      1         O     73
# 291448          840                  N  42044    0      1         O     73
# 291449          845                  N  37964    0      1         I     80
# 291450          849                  N  37964    0      1         O     47
#
# ...

# %%
df.shape
# Out:
# (291451, 24)

# %% [markdown]
# # Detecting Outlier

# %%
# Define the columns to be plotted

columns = ['CreditScore', 'MIP', 'Units', 'OCLTV', 'DTI', 'OrigUPB', 
           'LTV', 'OrigInterestRate', 'OrigLoanTerm', 'MonthsDelinquent', 'MonthsInRepayment']

# %%
# Create boxplots for each numerical column before handling outliers

plt.figure(figsize=(16, 10))
for i, column in enumerate(columns, start=1):
    plt.subplot(3, 4, i)
    sns.boxplot(df[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Handle Outlier and Capping them

# %%
# Handle outliers using IQR and capping them

for column in columns:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Cap outliers
    df[column] = df[column].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))

# %%
print("Shape of DataFrame after handling outliers:", df.shape)
# Out:
# Shape of DataFrame after handling outliers: (252060, 24)

# %% [markdown]
# # After handling Outlier

# %%
# Create boxplots for each numerical column after handling outliers

plt.figure(figsize=(16, 10))
for i, column in enumerate(columns, start=1):
    plt.subplot(3, 4, i)
    sns.boxplot(df[column])
    plt.title(f"After: {column}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Encoding

# %%
df['FirstTimeHomebuyer'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
order_label={'N':1,'Y':2}

# %%
df['FirstTimeHomebuyer']=df['FirstTimeHomebuyer'].map(order_label)

# %%
df['Occupancy'].unique()
# Out:
# array(['O', 'I', 'S'], dtype=object)

# %%
order_label={'O':1,'I':2,'S':3}

# %%
df['Occupancy']=df['Occupancy'].map(order_label)

# %%
df['Channel'].unique()
# Out:
# array(['T', 'R', 'C', 'B'], dtype=object)

# %%
order_label={'T':1,'R':2,'C':3,''}

# %%
df['Channel']=df['Channel'].map(order_label)

# %%
df['PPM'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df['PPM'] = df['PPM'].replace({'N':0,'Y':1})
# Out:
# C:\Users\rehan\AppData\Local\Temp\ipykernel_31696\379817675.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['PPM'] = df['PPM'].replace({'N':0,'Y':1})

# %%
df['PropertyState'].unique()
# Out:
# array(['IL', 'CO', 'KS', 'CA', 'NJ', 'FL', 'CT', 'GA', 'TX', 'MD', 'MA',
#        'SC', 'WY', 'NC', 'AZ', 'IN', 'MS', 'NY', 'WA', 'AR', 'VA', 'WI',
#        'MN', 'LA', 'PA', 'OR', 'RI', 'UT', 'MI', 'MO', 'IA', 'NM', 'OH',
#        'NE', 'AL', 'VT', 'HI', 'TN', 'NV', 'PR', 'DC', 'KY', 'SD', 'ME',
#        'NH', 'ID', 'MT', 'OK', 'WV', 'DE', 'ND', 'AK'], dtype=object)

# %%
df=pd.get_dummies(df,columns=['PropertyState'],drop_first=True)

# %%
df['PropertyType'].unique()
# Out:
# array(['SF', 'PU', 'CO', 'MH', 'CP', 'LH', 'X '], dtype=object)

# %%
df=pd.get_dummies(df,columns=['PropertyType'],drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252060 entries, 0 to 291450
# Data columns (total 79 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CreditScore         252060 non-null  float64
#  1   FirstTimeHomebuyer  252060 non-null  int64
#  2   MSA                 252060 non-null  int64
#  3   MIP                 252060 non-null  int64
#  4   Units               252060 non-null  float64
#  5   Occupancy           252060 non-null  int64
#  6   OCLTV               252060 non-null  float64
#  7   DTI                 252060 non-null  float64
#  8   OrigUPB             252060 non-null  float64
#  9   LTV                 252060 non-null  float64
#  10  OrigInterestRate    252060 non-null  float64
#  11  Channel             252060 non-null  int64
#  12  PPM                 252060 non-null  int64
#  13  PostalCode          252060 non-null  int64
#  14  LoanPurpose         252060 non-null  object
# ...

# %%
df['SellerName'].unique()
# Out:
# array(['FL', 'FT', 'GM', 'NO', 'Ot', 'ST', 'CR', 'CH', 'FI', 'HO', 'PR',
#        'PN', 'WA', 'BA', 'G ', 'OL', 'AC', 'RE', 'CO', 'BI'], dtype=object)

# %%
df=pd.get_dummies(df,columns=['SellerName'],drop_first=True)

# %%
df['LoanPurpose'].unique()
# Out:
# array(['P', 'N', 'C'], dtype=object)

# %%
order_label={'P':1,'N':2,'C':3}

# %%
df['LoanPurpose']=df['LoanPurpose'].map(order_label)

# %%
df['ServicerName'].unique()
# Out:
# array(['WASHINGTONMUTUALBANK', 'CHASEHOMEFINANCELLC ',
#        'GMACMTGECORP        ', 'WELLSFARGOBANKNA   ',
#        'Other servicers     ', 'ABNAMROMTGEGROUPINC',
#        'BANKOFAMERICANA    ', 'CHASEMANHATTANMTGECO',
#        'HOMESIDELENDINGINC ', 'CHASEMTGECO         ',
#        'WELLSFARGOHOMEMORTGA', 'PRINCIPALRESIDENTIAL',
#        'CITIMORTGAGEINC    ', 'JPMORGANCHASEBANKNA',
#        'BAMORTGAGELLC      ', 'NATLCITYMTGECO      ',
#        'FTMTGESERVICESINC  ', 'SUNTRUSTMORTGAGEINC',
#        'COUNTRYWIDE         ', 'FIFTHTHIRDBANK      '], dtype=object)

# %%
df=pd.get_dummies(df,columns=['ServicerName'],drop_first=True)

# %%
non_numeric_columns = df.select_dtypes(include=['object']).columns

# Check if there are any non-numeric values
if len(non_numeric_columns) > 0:
    print("Dataset contains non-numeric values in the following columns:")
    print(non_numeric_columns)
else:
    print("Dataset contains only numeric values.")
# Out:
# Dataset contains only numeric values.

# %% [markdown]
# # Create new Column

# %%
# Define bins and labels for credit score ranges
bins = [0,200,400,600,800,1000]
labels = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']

# %%
# Create a new column based on credit score range
df['CreditScoreRange'] = pd.cut(df['CreditScore'], bins=bins, labels=labels, right=False)
df.sample(5)
# Out:
#         CreditScore  FirstTimeHomebuyer    MSA  MIP  Units  Occupancy  OCLTV  \
# 248999        767.0                   1  48620    0    1.0          1   80.0
# 45647         655.0                   1  23580    0    1.0          1   69.0
# 121968        704.0                   2  14484    0    1.0          1   80.0
# 12207         617.0                   1  19740   29    1.0          1   89.0
# 45618         655.0                   1  12060    0    1.0          1   66.0
#
#          DTI   OrigUPB   LTV  OrigInterestRate  Channel  PPM  PostalCode  \
# 248999  15.0  113000.0  80.0             6.625        2    0       67000
# 45647   48.0  240000.0  69.0             6.500        2    0       30500
# 121968  34.0  186000.0  80.0             6.625        1    0        2000
# 12207   33.0  108000.0  89.0             6.875        1    0       80000
# 45618   25.0   58000.0  66.0             6.875        2    0       30100
#
# ...

# %%
# Define bins and labels for MonthsInRepayment range
bins = [0, 30, 60, 90, 120, 150, 180, 210]
labels = ['Bin1', 'Bin2', 'Bin3', 'Bin4', 'Bin5', 'Bin6', 'Bin7']

# %%
# Create a new column based on MonthsInRepayment Range
df['MonthsInRepaymentRange'] = pd.cut(df['MonthsInRepayment'], bins=bins,labels=labels,right=False)
df.sample(5)
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 68691         672.0                  N  35004    0    1.0         O   80.0
# 31617         642.0                  N  X       25    1.0         O   90.0
# 14043         621.0                  N  38300    0    1.0         O   57.0
# 33009         644.0                  N  X       25    1.0         O   87.0
# 208284        748.0                  N  36420    0    1.0         O   80.0
#
#          DTI   OrigUPB   LTV  OrigInterestRate Channel PPM PropertyState  \
# 68691   32.0  102000.0  80.0            7.1250       R   N            NY
# 31617   18.0   95000.0  90.0            7.6875       T   N            FL
# 14043   27.0  176000.0  57.0            6.6250       T   N            PA
# 33009   38.0   85000.0  87.0            7.0000       R   N            IL
# 208284  31.0  116000.0  80.0            6.7500       T   N            OK
#
#        PropertyType PostalCode LoanPurpose  OrigLoanTerm NumBorrowers  \
# ...

# %%
# Define bins and labels for LTV ranges
bins = [0,25,50,75,100,125]
labels = ['Poor', 'Fair', 'Good', 'Very Good', 'Excellent']

# %%
# Create a new column based on LTV Range
df['LTVRange'] = pd.cut(df['LTV'], bins=bins,labels=labels,right=False)
df.sample(5)
# Out:
#         CreditScore FirstTimeHomebuyer    MSA  MIP  Units Occupancy  OCLTV  \
# 215442        751.0                  N  17660   30    1.0         O   95.0
# 39443         650.0                  N  41884    0    1.0         O   66.0
# 210820        749.0                  Y  33460   30    1.0         O   95.0
# 28922         640.0                  N  33124    0    1.0         O   80.0
# 224251        755.0                  N  36084    0    1.0         O   50.0
#
#          DTI   OrigUPB   LTV  OrigInterestRate Channel PPM PropertyState  \
# 215442  38.0  117000.0  95.0             7.000       T   N            ID
# 39443   53.0  230000.0  66.0             6.250       T   N            CA
# 210820  32.0  169000.0  95.0             6.875       T   N            MN
# 28922   43.0   70000.0  80.0             6.875       T   N            FL
# 224251  25.0  224000.0  50.0             6.875       R   N            CA
#
#        PropertyType PostalCode LoanPurpose  OrigLoanTerm NumBorrowers  \
# ...

# %%
df['CreditScoreRange'].unique()
# Out:
# ['Good', 'Very Good', 'Excellent']
# Categories (5, object): ['Poor' < 'Fair' < 'Good' < 'Very Good' < 'Excellent']

# %%
order_label={'Poor':1,'Fair':2,'Good':3,'Very Good':4,'Excellent':5}

# %%
df['CreditScoreRange']=df['CreditScoreRange'].map(order_label)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252060 entries, 0 to 291450
# Columns: 116 entries, CreditScore to CreditScoreRange
# dtypes: bool(95), category(1), float64(10), int64(10)
# memory usage: 71.5 MB
